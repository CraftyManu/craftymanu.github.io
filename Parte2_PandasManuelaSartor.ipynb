# %% [markdown]
# # Baboon Mating and Genetic Admixture
# Data on genetic admixture and likelihood of successful mating between baboons

# %%
import pandas as pd

# %%
df = pd.read_csv("D:/Manu/Programacion/CursoTicmasAcademyPython/kaggleDataSets/BaboonMatingandGeneticAdmixture/baboon_mating.csv", sep = ",", low_memory = False)
# Origen: https://www.kaggle.com/datasets/dryad/baboon-mating

# %%
type(df) #la estructura del df es la adecuada
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   female_id male_id  cycle_id  consort  conceptive  female_hybridscore  \
# 0       ABB     LUI      5068        1           0            0.307333
# 1       ABB     IAG      5068        0           0            0.307333
# 2       ABB     LAX      5068        0           0            0.307333
# 3       ABB     LEB      5068        0           0            0.307333
# 4       ABB     NAW      5068        0           0            0.307333
# 5       ABB     ZIB      5068        0           0            0.307333
# 6       ABB     LUI      5073        1           0            0.307333
# 7       ABB     FIG      5073        0           0            0.307333
# 8       ABB     IAG      5073        0           0            0.307333
# 9       ABB     LAX      5073        0           0            0.307333
#
#    male_hybridscore  female_gendiv  male_gendiv  gen_distance  female_age  \
# 0          0.465667         0.7857       0.9286        0.0335    7.156742
# ...

# %%
df.tail(10)
# Out:
#       female_id male_id  cycle_id  consort  conceptive  female_hybridscore  \
# 12131       YOG     LOF     27526        0           0               0.416
# 12132       YOG     LOG     27526        0           0               0.416
# 12133       YOG     QUA     27526        0           0               0.416
# 12134       YOG     THR     27526        0           0               0.416
# 12135       YOG     GAN     27529        0           1               0.416
# 12136       YOG     GYP     27529        0           1               0.416
# 12137       YOG     LOF     27529        0           1               0.416
# 12138       YOG     LOG     27529        0           1               0.416
# 12139       YOG     QUA     27529        0           1               0.416
# 12140       YOG     THR     27529        0           1               0.416
#
#        male_hybridscore  female_gendiv  male_gendiv  gen_distance  female_age  \
# ...

# %%
print(df.shape) #12141 observaciones y 20 columnas
# Out:
# (12141, 20)

# %%
#Listado de las columnas
print(df.columns)
# Out:
# Index(['female_id', 'male_id', 'cycle_id', 'consort', 'conceptive',
#        'female_hybridscore', 'male_hybridscore', 'female_gendiv',
#        'male_gendiv', 'gen_distance', 'female_age', 'male_rank', 'female_rank',
#        'males_present', 'females_present', 'male_rank_transform',
#        'gen_distance_transform', 'rank_interact', 'assort_index',
#        'female_age_transform'],
#       dtype='object')

# %%
df.dtypes
# Out:
# female_id                  object
# male_id                    object
# cycle_id                    int64
# consort                     int64
# conceptive                  int64
# female_hybridscore        float64
# male_hybridscore          float64
# female_gendiv             float64
# male_gendiv               float64
# gen_distance              float64
# female_age                float64
# male_rank                   int64
# female_rank                 int64
# males_present               int64
# females_present             int64
# male_rank_transform       float64
# gen_distance_transform    float64
# rank_interact               int64
# assort_index              float64
# female_age_transform      float64
# dtype: object

# %%
df.count() #totalidad de registros por columna
# Out:
# female_id                 12141
# male_id                   12141
# cycle_id                  12141
# consort                   12141
# conceptive                12141
# female_hybridscore        12141
# male_hybridscore          12141
# female_gendiv             12141
# male_gendiv               12141
# gen_distance              12141
# female_age                12141
# male_rank                 12141
# female_rank               12141
# males_present             12141
# females_present           12141
# male_rank_transform       12141
# gen_distance_transform    12141
# rank_interact             12141
# assort_index              12141
# female_age_transform      12141
# dtype: int64

# %%
#Determinar cuantos valores faltantes tenemos en cada columna -> no hay valores faltantes.
print(df.isna().sum())
# Out:
# female_id                 0
# male_id                   0
# cycle_id                  0
# consort                   0
# conceptive                0
# female_hybridscore        0
# male_hybridscore          0
# female_gendiv             0
# male_gendiv               0
# gen_distance              0
# female_age                0
# male_rank                 0
# female_rank               0
# males_present             0
# females_present           0
# male_rank_transform       0
# gen_distance_transform    0
# rank_interact             0
# assort_index              0
# female_age_transform      0
# dtype: int64

# %%
# df_resumido = sólo incluye a las hembras con concepciones registradas (conceptive = 1) y los machos con los que se aparearon (consort = 1): 
df_resumido = df[(df.conceptive > 0) & (df.consort > 0)] 
df_resumido.drop(columns = ['cycle_id'], inplace = True)
# Out:
# C:\Users\Manu\AppData\Local\Temp\ipykernel_5980\1527647158.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_resumido.drop(columns = ['cycle_id'], inplace = True)

# %%
df_resumido.shape
# Out:
# (523, 19)

# %%
df_resumido.head()
# Out:
#     female_id male_id  consort  conceptive  female_hybridscore  \
# 53        ABB     ZIB        1           1            0.307333
# 97        ACA     LEB        1           1            0.077667
# 98        ACA     IAG        1           1            0.077667
# 113       ACA     LOB        1           1            0.077667
# 118       ACA     ZIB        1           1            0.077667
#
#      male_hybridscore  female_gendiv  male_gendiv  gen_distance  female_age  \
# 53           0.635000         0.7857       0.7692        0.0716    7.863107
# 97           0.476667         0.7857       0.7857       -0.0826    8.432580
# 98           0.213333         0.7857       0.7143       -0.0858    8.432580
# 113          0.652333         0.7857       0.9231       -0.1263    9.754962
# 118          0.635000         0.7857       0.7692       -0.0826    9.976728
#
#      male_rank  female_rank  males_present  females_present  \
# 53           6            2              6                9
# ...

# %%
print(df_resumido.columns)
# Out:
# Index(['female_id', 'male_id', 'consort', 'conceptive', 'female_hybridscore',
#        'male_hybridscore', 'female_gendiv', 'male_gendiv', 'gen_distance',
#        'female_age', 'male_rank', 'female_rank', 'males_present',
#        'females_present', 'male_rank_transform', 'gen_distance_transform',
#        'rank_interact', 'assort_index', 'female_age_transform'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12141 entries, 0 to 12140
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   female_id               12141 non-null  object
#  1   male_id                 12141 non-null  object
#  2   cycle_id                12141 non-null  int64
#  3   consort                 12141 non-null  int64
#  4   conceptive              12141 non-null  int64
#  5   female_hybridscore      12141 non-null  float64
#  6   male_hybridscore        12141 non-null  float64
#  7   female_gendiv           12141 non-null  float64
#  8   male_gendiv             12141 non-null  float64
#  9   gen_distance            12141 non-null  float64
#  10  female_age              12141 non-null  float64
#  11  male_rank               12141 non-null  int64
#  12  female_rank             12141 non-null  int64
#  13  males_present           12141 non-null  int64
# ...

# %%
df.drop(columns = ['cycle_id'], inplace = True)

# %%
df.describe()
# Out:
#             consort    conceptive  female_hybridscore  male_hybridscore  \
# count  12141.000000  12141.000000        12141.000000      12141.000000
# mean       0.135738      0.286385            0.194999          0.293797
# std        0.342525      0.452090            0.199030          0.232620
# min        0.000000      0.000000            0.029333          0.029333
# 25%        0.000000      0.000000            0.051667          0.091333
# 50%        0.000000      0.000000            0.087667          0.214000
# 75%        0.000000      1.000000            0.286333          0.499000
# max        1.000000      1.000000            0.745333          1.000000
#
#        female_gendiv   male_gendiv  gen_distance    female_age     male_rank  \
# count   12141.000000  12141.000000  12141.000000  12141.000000  12141.000000
# mean        0.820956      0.838202     -0.014891     11.441684      5.516102
# std         0.101720      0.117108      0.139124      4.525563      3.354680
# ...

# %%
df_resumido.describe()
# Out:
#        consort  conceptive  female_hybridscore  male_hybridscore  \
# count    523.0       523.0          523.000000        523.000000
# mean       1.0         1.0            0.177242          0.316096
# std        0.0         0.0            0.190296          0.234580
# min        1.0         1.0            0.029333          0.029333
# 25%        1.0         1.0            0.045667          0.071167
# 50%        1.0         1.0            0.081667          0.311000
# 75%        1.0         1.0            0.240833          0.514667
# max        1.0         1.0            0.745333          1.000000
#
#        female_gendiv  male_gendiv  gen_distance  female_age   male_rank  \
# count     523.000000   523.000000    523.000000  523.000000  523.000000
# mean        0.807889     0.852659     -0.027734   10.958146    3.789675
# std         0.104545     0.112546      0.133559    3.594363    2.665540
# min         0.500000     0.500000     -0.330000    4.999316    1.000000
# ...

# %%
df.describe().T
# Out:
#                           count       mean        std       min        25%  \
# consort                 12141.0   0.135738   0.342525  0.000000   0.000000
# conceptive              12141.0   0.286385   0.452090  0.000000   0.000000
# female_hybridscore      12141.0   0.194999   0.199030  0.029333   0.051667
# male_hybridscore        12141.0   0.293797   0.232620  0.029333   0.091333
# female_gendiv           12141.0   0.820956   0.101720  0.500000   0.714300
# male_gendiv             12141.0   0.838202   0.117108  0.500000   0.785700
# gen_distance            12141.0  -0.014891   0.139124 -0.333300  -0.113600
# female_age              12141.0  11.441684   4.525563  4.993840   7.797399
# male_rank               12141.0   5.516102   3.354680  1.000000   3.000000
# female_rank             12141.0   9.851413   6.763576  1.000000   4.000000
# males_present           12141.0   9.914916   3.002897  2.000000   8.000000
# ...

# %%
import matplotlib.pyplot as plt

df.plot()

plt.show()

# %%
df_resumido.plot()

plt.show()

# %%
df.plot(kind = 'scatter', x = 'male_rank', y = 'male_rank_transform')

plt.show()
